# %%
pip install wikipedia
# Out:
# Collecting wikipedia
#   Using cached wikipedia-1.4.0-py3-none-any.whl
# Collecting beautifulsoup4 (from wikipedia)
#   Using cached beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in i:\Porashuna\Course\Langchain\.venv\Lib\site-packages (from wikipedia) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in i:\Porashuna\Course\Langchain\.venv\Lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in i:\Porashuna\Course\Langchain\.venv\Lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in i:\Porashuna\Course\Langchain\.venv\Lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in i:\Porashuna\Course\Langchain\.venv\Lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2026.2.25)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4->wikipedia)
#   Using cached soupsieve-2.8.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in i:\Porashuna\Course\Langchain\.venv\Lib\site-packages (from beautifulsoup4->wikipedia) (4.15.0)
# Using cached beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Using cached soupsieve-2.8.3-py3-none-any.whl (37 kB)
# Installing collected packages: soupsieve, beautifulsoup4, wikipedia
#
#    ---------------------------------------- 0/3 [soupsieve]
#    ------------- -------------------------- 1/3 [beautifulsoup4]
#    ------------- -------------------------- 1/3 [beautifulsoup4]
#    ---------------------------------------- 3/3 [wikipedia]
#
# Successfully installed beautifulsoup4-4.14.3 soupsieve-2.8.3 wikipedia-1.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
print(sys.executable)
# Out:
# i:\Porashuna\Course\Langchain\.venv\Scripts\python.exe

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# #### Text Doc Loader

# %%
from langchain_community.document_loaders import TextLoader

# %%
loader = TextLoader("../data/speech.txt")
texts = loader.load()

# %%
texts
oneDoc = texts[0]
print(oneDoc.page_content)
# Out:
# “My dear friends, students, and respected farmers,
#
# Today, I want to speak from the heart about three pillars that define the future of our nation:
# our youth, our education system, and our farmers.
#
# 🎓 For the Youth
#
# You are the energy that drives our state forward.
# Our commitment is to give you:
# 	•	Skill-based education
# 	•	Digital learning opportunities
# 	•	Better employment pathways
# 	•	Support for innovation, startups, and entrepreneurship
#
# Your dreams are not just your own—they are the dreams of our entire society.
#
# 📚 For Education
#
# Education must not be just a formality; it must be a force of transformation.
# We aim to:
# 	•	Upgrade government schools with smart classrooms
# 	•	Improve teacher training
# 	•	Expand scholarships for higher education
# 	•	Promote technical and vocational courses
# 	•	Ensure every child gets a fair opportunity to learn and grow
#
# Education is the foundation on which we will build tomorrow.
#
# 👨‍🌾 For Farmers
#
# Our farmers are our pride.
# We honor their hard work and promise them:
# 	•	Better irrigation systems
# 	•	Access to modern farming technology
# 	•	Fair and timely MSP
# 	•	Improved cold storage and transport facilities
# 	•	Easier access to credit and crop insurance
#
# A nation that respects its farmers grows stronger every day.
#
# Friends,
# If we empower our youth, strengthen our education system, and support our farmers, no force can stop us from achieving prosperity.
#
# Let us walk this path together—towards growth, stability, and a brighter future.
#
# Thank you. Jai Hind.”

# %% [markdown]
# #### PDF Doc Loader

# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader("../data/medical_report.pdf")

# %%
pdf = loader.load()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File i:\Porashuna\Course\Langchain\.venv\Lib\site-packages\langchain_community\document_loaders\parsers\pdf.py:359, in PyPDFParser.lazy_parse(self, blob)
#     358 try:
# --> 359     import pypdf
#     360 except ImportError:
#
# ModuleNotFoundError: No module named 'pypdf'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 pdf = loader.load()
#
# File i:\Porashuna\Course\Langchain\.venv\Lib\site-packages\langchain_core\document_loaders\base.py:43, in BaseLoader.load(self)
#      37 def load(self) -> list[Document]:
#      38     """Load data into `Document` objects.
#      39
#      40     Returns:
#      41         The documents.
#      42     """
# ---> 43     return list(self.lazy_load())
#
# File i:\Porashuna\Course\Langchain\.venv\Lib\site-packages\langchain_community\document_loaders\pdf.py:305, in PyPDFLoader.lazy_load(self)
#     303 else:
#     304     blob = Blob.from_path(self.file_path)
# --> 305 yield from self.parser.lazy_parse(blob)
#
# File i:\Porashuna\Course\Langchain\.venv\Lib\site-packages\langchain_community\document_loaders\parsers\pdf.py:361, in PyPDFParser.lazy_parse(self, blob)
#     359     import pypdf
#     360 except ImportError:
# --> 361     raise ImportError(
#     362         "`pypdf` package not found, please install it with `pip install pypdf`"
#     363     )
#     365 def _extract_text_from_page(page: pypdf.PageObject) -> str:
#     366     """
#     367     Extract text from image given the version of pypdf.
#     368
#    (...)    373         str: The extracted text.
#     374     """
#
# ImportError: `pypdf` package not found, please install it with `pip install pypdf`

# %%
oneDoc = pdf[0]
print(oneDoc.page_content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 oneDoc = pdf[0]
#       2 print(oneDoc.page_content)
#
# NameError: name 'pdf' is not defined

# %%
from langchain_community.document_loaders import WikipediaLoader

loader = WikipediaLoader(query="Gen AI", load_max_docs=2)
docs = loader.load()

print(len(docs))
# Out:
# 2

# %%
docs[0].page_content
# Out:
# 'Generative artificial intelligence, also known as generative AI or GenAI, is a subfield of artificial intelligence that uses generative models to generate text, images, videos, audio, software code or other forms of data. These models learn the underlying patterns and structures of their training data, and use them to generate new data in response to input, which often takes the form of natural language prompts.\nThe prevalence of generative AI tools has increased significantly since the AI boom in the 2020s. This boom was made possible by improvements in deep neural networks, particularly large language models (LLMs), which are based on the transformer architecture. Generative AI applications include chatbots such as ChatGPT, Claude, Copilot, DeepSeek, Google Gemini and Grok; text-to-image models such as Stable Diffusion, Flux, Midjourney, and DALL-E; and text-to-video models such as Veo, LTX and Sora.\nCompanies in a variety of sectors have used generative AI, including those in software development, healthcare, finance, entertainment, customer service, sales and marketing, art, writing, and product design.  \nGenerative AI has been used for cybercrime, and to deceive and manipulate people through fake news and deepfakes. Generative AI models have been trained on copyrighted works without the rightholders\' permission. Many generative AI systems use large-scale data centers whose environmental impacts include e-waste, consumption of fresh water for cooling, and high energy consumption that is estimated to be growing steadily.\n\n\n== History ==\n\n\n=== Early history ===\nThe origins of algorithmically generated media can be traced to the development of the Markov chain, which has been used to model natural language since the early 20th century. Russian mathematician Andrey Markov introduced the concept in 1906, including an analysis of vowel and consonant patterns in Eugeny Onegin. Once trained on a text corpus, a Markov chain can generate probabilistic text.\nBy the early 1970s, artists began using computers to extend generative techniques beyond Markov models. Harold Cohen developed and exhibited works produced by AARON, a pioneering computer program designed to autonomously create paintings.\nThe terms generative AI planning or generative planning were used in the 1980s and 1990s to refer to AI planning systems, especially computer-aided process planning, used to generate sequences of actions to reach a specified goal. Generative AI planning systems used symbolic AI methods such as state space search and constraint satisfaction and were a "relatively mature" technology by the early 1990s. They were used to generate crisis action plans for military use, process plans for manufacturing and decision plans such as in prototype autonomous spacecraft.\n\n\n=== Generative neural networks (since the late 2000s) ===\n\nMachine learning uses both discriminative models and generative models to predict data. Beginning in the late 2000s, the introduction of deep learning technology led to improvements in image classification, speech recognition, natural language processing and other tasks. Neural networks in this era were typically trained as discriminative models due to the difficulty of generative modeling.\nIn 2014, advancements such as the variational autoencoder and generative adversarial network produced the first practical deep neural networks capable of learning generative models, as opposed to discriminative ones, for complex data such as images. These deep generative models were the first to output not only class labels for images but also entire images, such as DeepDream.\nIn 2017, the Transformer network enabled advancements in generative models compared to older long short-term memory (LSTM) models, leading to the first generative pre-trained transformer (GPT), known as GPT-1, in 2018.\n\n\n=== Generative AI adoption ===\n\nIn March 2020, the release of 15.ai, a free web application created by an anonymous MIT researche ...
